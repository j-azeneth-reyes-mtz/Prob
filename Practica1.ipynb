# %% [markdown]
# <a href="https://colab.research.google.com/github/j-azeneth-reyes-mtz/Probabilidad/blob/main/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadística
# ## Unidad 1
# ### Facilitador: José Gabriel Rodriguez Rivas
# ### Alumno: Judith Azeneth Reyes Martínez
# ### **Programa 1: estadística basica o Histogramas**

# %%
from stadistics import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-498602652.py in <cell line: 0>()
# ----> 1 from stadistics import *
#
# ModuleNotFoundError: No module named 'stadistics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# lista de calificaciones del grado a de probabilidad y estadistica
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 70, 100, 95]
print (grupoa)
type(grupoa)

# %%
[70, 70, 65, 90, 100, 95, 45, 80, 73, 70, 100, 95]
list

# %%
# sacar la media de las calificaciones con una formula
promedio = sum(grupoa) / len(grupoa)

# %%
# utilizar la funcion

# %%
#Determinar el valor de la mediana con la funcion media
mediana = media(grupoa)
print(mediana)

# %%
#Determinar el valor moda con la funcion moda
moda = mode(grupoa)
print(moda)

# %%
moda2 = multomode(grupoa)
print(moda2)

# %%
tiemposlimites = [15.16, 17.20, 14.65, 11.27, 15.15, 16.71, 19.15, 20.65, 15.10, 17.20]
print(tiemposlimites)
promedio = sum(tiemposlimites) / len(tiempos_limites)
print("El tiempo promedio de los corredores:" mediana)

# %%
#Libreria para agrupar por numros aleatorios
import random

# %%
fabrica1 = []
for i in range (100):
  numero_aleatorio = round(random.uniform(0,100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [53.14, 24.58, 56.09, 57.62, 21.13, 18.77, 95.85, 24.96, 42.74, 86.4, 22.11, 58.55, 23.08, 37.69, 87.0, 37.67, 85.95, 6.91, 11.03, 44.16, 59.83, 87.84, 5.79, 90.55, 70.0, 46.23, 62.88, 13.04, 53.82, 60.72, 94.26, 93.64, 71.69, 61.28, 83.57, 57.85, 19.39, 39.9, 98.35, 55.49, 73.01, 19.0, 45.41, 20.83, 29.08, 22.16, 15.94, 36.55, 9.83, 64.46, 53.77, 67.08, 6.4, 65.01, 2.84, 65.51, 28.09, 23.64, 56.23, 5.83, 63.75, 69.14, 8.12, 99.52, 98.98, 53.64, 26.93, 21.72, 94.13, 0.06, 34.05, 23.99, 93.49, 32.29, 81.53, 71.75, 72.97, 10.44, 96.78, 60.41, 58.83, 7.1, 44.08, 95.08, 65.7, 41.19, 83.53, 99.33, 62.1, 78.34, 55.34, 13.09, 55.0, 30.84, 81.29, 61.43, 81.68, 98.27, 33.34, 68.05]

# %%
fabrica2 = []
for i in range (100):
  numero_aleatorio = round(random.uniform(0,100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [99.66, 31.57, 70.49, 33.36, 30.03, 88.67, 69.87, 31.17, 81.73, 83.89, 44.36, 23.66, 2.0, 34.25, 47.64, 38.02, 81.17, 86.93, 50.69, 82.47, 64.15, 50.3, 73.43, 26.04, 81.64, 58.88, 30.43, 67.38, 73.29, 16.72, 11.28, 3.85, 8.49, 51.5, 23.19, 72.52, 34.35, 86.42, 74.28, 25.22, 30.72, 62.31, 70.81, 45.39, 29.08, 54.5, 41.71, 23.99, 11.95, 44.63, 60.73, 90.19, 80.48, 13.15, 71.33, 23.91, 96.65, 79.08, 79.89, 5.71, 90.9, 63.13, 90.22, 14.52, 56.16, 7.25, 43.26, 50.48, 78.45, 63.59, 93.73, 61.81, 13.1, 94.38, 67.36, 6.21, 25.99, 74.58, 1.74, 92.42, 31.94, 75.95, 61.7, 27.57, 53.58, 43.83, 52.96, 53.93, 37.37, 15.08, 22.71, 28.36, 91.54, 67.02, 35.71, 30.63, 47.28, 42.1, 62.79, 89.08]

# %%
#Libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica')

# %%
media = mean(fabrica1)
mediana = median(fabrica1)
mada = mode(fabrica1)

print("valores de la fabrica")
print("la media es:" media)
print("la mediana es:" mediana)
print("la moda es:" moda)

# %%
media = mean(fabrica1)
mediana = median(fabrica1)
mada = mode(fabrica1)

print("valores de la fabrica")
print("la media es:" media)
print("la mediana es:" mediana)
print("la moda es:" moda)

# %%
fig, (ax1, ax2) = plt.subplot(around =1)
